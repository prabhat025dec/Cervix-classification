# %%
from google.colab import drive
drive.mount('/content/gdrive')
import cv2
import os
import random
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import tensorflow as tf
import tensorflow.keras as keras

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_dir = "/content/gdrive/MyDrive/AGCCPF/train"
test_dir = "/content/gdrive/MyDrive/AGCCPF/test"
valid_dir = "/content/gdrive/MyDrive/AGCCPF/validate"

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# !unzip AGCCPF.zip

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=20,
        class_mode='categorical',
        shuffle=True
        )

valid_generator = test_datagen.flow_from_directory(
        valid_dir,
        target_size=(224, 224),
        batch_size=20,
        class_mode='categorical',
        shuffle=True
        )

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=20,
        class_mode='categorical',
        shuffle=False
        )
# Out:
# Found 5253 images belonging to 3 classes.
# Found 1315 images belonging to 3 classes.
# Found 1644 images belonging to 3 classes.

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
from tensorflow.keras import optimizers

# %%
input_layer=layers.Input((224, 224, 3))
from tensorflow.keras.applications import VGG16,DenseNet121
conv_base_1 = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))(input_layer)


# conv_base = EfficientNetB7(weights='imagenet',
#                   include_top=False,
#                   input_shape=(200, 200, 3))

conv_base_2 = DenseNet121(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))(input_layer)

# conv_base = MobileNetV2(weights='imagenet',
#                   include_top=False,
#                   input_shape=(224, 224, 3))

# %%
# model_1 = keras.models.Sequential()
model_1=conv_base_1
model_1=keras.layers.GlobalAveragePooling2D()(model_1)
model_1=keras.layers.Dense(3, activation='softmax')(model_1)

# model_2 = keras.models.Sequential()
model_2=conv_base_2
model_2=keras.layers.GlobalAveragePooling2D()(model_2)
model_2=keras.layers.Dense(3, activation='softmax')(model_2)

merge=layers.Concatenate()([model_1,model_2])
result=layers.Dense(3, activation='softmax')(merge)

model=keras.models.Model(input_layer,result)

# %%
# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation='relu',
#                         input_shape=(150, 150, 3)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(128, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(128, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Flatten())
# model.add(layers.Dropout(0.5))
# model.add(layers.Dense(512, activation='relu'))
# model.add(layers.Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-5),
              metrics=['acc',tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "MobileNet_model.h5", save_best_only=True)
earlystop_cb = keras.callbacks.EarlyStopping(
    patience=5, restore_best_weights=True)

# %%
model.summary(0)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, 7, 7, 512)    14714688    ['input_3[0][0]']
#
#  densenet121 (Functional)       (None, 7, 7, 1024)   7037504     ['input_3[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 512)         0           ['vgg16[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_5 (Gl  (None, 1024)        0           ['densenet121[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 3)            1539        ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_7 (Dense)                (None, 3)            3075        ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  concatenate_2 (Concatenate)    (None, 6)            0           ['dense_6[0][0]',
#                                                                   'dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 3)            21          ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 21,756,827
# Trainable params: 21,673,179
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
history = model.fit(train_generator,
                    steps_per_epoch=260,
                    epochs=50,
                    validation_data=valid_generator,
                    validation_steps=60,
                    callbacks=[checkpoint_cb])
# Out:
# Epoch 1/50
# 260/260 [==============================] - 1464s 5s/step - loss: 1.0352 - acc: 0.4437 - recall: 0.0875 - precision: 0.5673 - val_loss: 0.9650 - val_acc: 0.5625 - val_recall: 0.1425 - val_precision: 0.7037
# Epoch 2/50
# 260/260 [==============================] - 352s 1s/step - loss: 0.9425 - acc: 0.5556 - recall: 0.2588 - precision: 0.6452 - val_loss: 0.9224 - val_acc: 0.5733 - val_recall: 0.3158 - val_precision: 0.6591
# Epoch 3/50
# 260/260 [==============================] - 335s 1s/step - loss: 0.9114 - acc: 0.5844 - recall: 0.3636 - precision: 0.6583 - val_loss: 0.9095 - val_acc: 0.5983 - val_recall: 0.3642 - val_precision: 0.6445
# Epoch 4/50
# 260/260 [==============================] - 335s 1s/step - loss: 0.8881 - acc: 0.6114 - recall: 0.4132 - precision: 0.6830 - val_loss: 0.8974 - val_acc: 0.5992 - val_recall: 0.4158 - val_precision: 0.6497
# Epoch 5/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.8691 - acc: 0.6318 - recall: 0.4593 - precision: 0.6990 - val_loss: 0.9013 - val_acc: 0.6117 - val_recall: 0.5175 - val_precision: 0.6442
# Epoch 6/50
# 260/260 [==============================] - 336s 1s/step - loss: 0.8489 - acc: 0.6533 - recall: 0.4937 - precision: 0.7140 - val_loss: 0.8778 - val_acc: 0.6067 - val_recall: 0.4975 - val_precision: 0.6663
# Epoch 7/50
# 260/260 [==============================] - 335s 1s/step - loss: 0.8284 - acc: 0.6776 - recall: 0.5265 - precision: 0.7425 - val_loss: 0.8741 - val_acc: 0.6300 - val_recall: 0.5108 - val_precision: 0.6641
# Epoch 8/50
# 260/260 [==============================] - 334s 1s/step - loss: 0.8116 - acc: 0.6942 - recall: 0.5523 - precision: 0.7461 - val_loss: 0.8629 - val_acc: 0.6408 - val_recall: 0.5325 - val_precision: 0.6748
# Epoch 9/50
# 260/260 [==============================] - 335s 1s/step - loss: 0.7984 - acc: 0.6950 - recall: 0.5727 - precision: 0.7569 - val_loss: 0.8256 - val_acc: 0.6867 - val_recall: 0.5633 - val_precision: 0.7316
# Epoch 10/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.7871 - acc: 0.7154 - recall: 0.5883 - precision: 0.7740 - val_loss: 0.8770 - val_acc: 0.6275 - val_recall: 0.5508 - val_precision: 0.6417
# Epoch 11/50
# 260/260 [==============================] - 334s 1s/step - loss: 0.7656 - acc: 0.7321 - recall: 0.6255 - precision: 0.7859 - val_loss: 0.8212 - val_acc: 0.6742 - val_recall: 0.5992 - val_precision: 0.7233
# Epoch 12/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.7450 - acc: 0.7526 - recall: 0.6588 - precision: 0.8006 - val_loss: 0.8486 - val_acc: 0.6608 - val_recall: 0.6008 - val_precision: 0.6893
# Epoch 13/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.7414 - acc: 0.7551 - recall: 0.6645 - precision: 0.8024 - val_loss: 0.8303 - val_acc: 0.6692 - val_recall: 0.6058 - val_precision: 0.7051
# Epoch 14/50
# 260/260 [==============================] - 335s 1s/step - loss: 0.7261 - acc: 0.7672 - recall: 0.6852 - precision: 0.8127 - val_loss: 0.8192 - val_acc: 0.6700 - val_recall: 0.5992 - val_precision: 0.7126
# Epoch 15/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.7176 - acc: 0.7722 - recall: 0.6942 - precision: 0.8167 - val_loss: 0.8480 - val_acc: 0.6483 - val_recall: 0.5725 - val_precision: 0.6638
# Epoch 16/50
# 260/260 [==============================] - 334s 1s/step - loss: 0.7002 - acc: 0.7874 - recall: 0.7165 - precision: 0.8278 - val_loss: 0.7928 - val_acc: 0.7083 - val_recall: 0.6558 - val_precision: 0.7267
# Epoch 17/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.6868 - acc: 0.8003 - recall: 0.7337 - precision: 0.8375 - val_loss: 0.8159 - val_acc: 0.6883 - val_recall: 0.6250 - val_precision: 0.7163
# Epoch 18/50
# 260/260 [==============================] - 333s 1s/step - loss: 0.6798 - acc: 0.8070 - recall: 0.7391 - precision: 0.8431 - val_loss: 0.8116 - val_acc: 0.6817 - val_recall: 0.6342 - val_precision: 0.6982
# 260/260 [==============================] - 334s 1s/step - loss: 0.6702 - acc: 0.8142 - recall: 0.7537 - precision: 0.8434 - val_loss: 0.7892 - val_acc: 0.7033 - val_recall: 0.6508 - val_precision: 0.7245
# Epoch 20/50
# 260/260 [==============================] - 335s 1s/step - loss: 0.6542 - acc: 0.8246 - recall: 0.7666 - precision: 0.8530 - val_loss: 0.7813 - val_acc: 0.7092 - val_recall: 0.6708 - val_precision: 0.7385
# Epoch 21/50
# 225/260 [========================>.....] - ETA: 41s - loss: 0.6442 - acc: 0.8304 - recall: 0.7710 - precision: 0.8643

# %%
pd.DataFrame(history.history).plot(figsize=(10, 10))
plt.ylim((0,2))
plt.grid(True)
plt.show()

# %%
model.evaluate(test_generator)

# %%
x=model.predict(test_generator)

# %%
pred=np.argmax(x, axis=-1)
pred

# %%
actual=test_generator.labels
actual

# %%
pred=np.argmax(x, axis=-1)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(actual,pred)

# %%
x=model.predict(test_generator)
actual=test_generator.labels
pred=np.argmax(x, axis=-1)
from sklearn.metrics import confusion_matrix
confusion_matrix(actual,pred)
